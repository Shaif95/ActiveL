# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaif95/ActiveL/blob/main/AI_Camp_Updated_CV_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 7.8 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.27.1-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 8.4 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 14.0 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.0 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 8.8 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 7.6 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 13.2 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.15.0)
# Installing collected packages: tokenizers, xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.10.1 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.2 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.2 transformers-4.27.1 xxhash-3.2.0 yarl-1.8.2

# %%
# !pip install -q wandb
import wandb
# !wandb login --relogin "YOUR_KEY_HERE"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 16.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 6.6 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done
# Traceback (most recent call last):
#   File "/usr/local/bin/wandb", line 8, in <module>
#     sys.exit(cli())
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1130, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1055, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1657, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1404, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 760, in invoke
#     return __callback(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/wandb/cli/cli.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/wandb/cli/cli.py", line 248, in login
#     wandb.login(relogin=relogin, key=key, anonymous=anon_mode, host=host, force=True)
#   File "/usr/local/lib/python3.9/dist-packages/wandb/sdk/wandb_login.py", line 77, in login
#     configured = _login(**kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/wandb/sdk/wandb_login.py", line 292, in _login
#     wlogin.configure_api_key(key)
#   File "/usr/local/lib/python3.9/dist-packages/wandb/sdk/wandb_login.py", line 176, in configure_api_key
#     apikey.write_key(self._settings, key)
#   File "/usr/local/lib/python3.9/dist-packages/wandb/sdk/lib/apikey.py", line 222, in write_key
#     raise ValueError("API key must be 40 characters long, yours was %s" % len(key))
# ValueError: API key must be 40 characters long, yours was 13

# %%
from datasets import load_dataset

ds = load_dataset('GratedRacer08/dataset')
ds
# Out:
# Downloading and preparing dataset imagefolder/GratedRacer08--dataset to /root/.cache/huggingface/datasets/GratedRacer08___imagefolder/GratedRacer08--dataset-0389d3ad0de66806/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f...
# Downloading data files:   0%|          | 0/151 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/12.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.79k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.46k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.95k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.62k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.61k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.32k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.37k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.72k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.74k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.41k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.75k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.89k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.28k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.14k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.22k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.64k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/17.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.22k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.51k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.61k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/17.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.15k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.90k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.65k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.82k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.13k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.71k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.13k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.06k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.83k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.11k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.30k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.53k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.63k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.76k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.70k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.23k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.94k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.33k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.57k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.78k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.19k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.14k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.35k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.36k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.17k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.05k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.84k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.53k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.18k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.8k [00:00<?, ?B/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Downloading data files:   0%|          | 0/20 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/5.93k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.88k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.63k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.54k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.66k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.37k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.70k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.16k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.44k [00:00<?, ?B/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Downloading data files:   0%|          | 0/18 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/7.32k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.83k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.17k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.96k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.52k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.52k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.85k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset imagefolder downloaded and prepared to /root/.cache/huggingface/datasets/GratedRacer08___imagefolder/GratedRacer08--dataset-0389d3ad0de66806/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 151
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 20
#     })
#     validation: Dataset({
#         features: ['image', 'label'],
#         num_rows: 18
#     })
# })

# %%
from transformers import ViTFeatureExtractor

model_name_or_path = 'google/vit-base-patch16-224-in21k'
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name_or_path)
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
import os
def transform(example_batch):
    # Take a list of PIL images and turn them to pixel values
    inputs = feature_extractor([x for x in example_batch['image']], return_tensors='pt')

    # Don't forget to include the labels!
    inputs['label'] = example_batch['label']
    return inputs

prepared_ds = ds.with_transform(transform)
os.environ["WANDB_PROJECT"]="train"

# save your trained model checkpoint to wandb
os.environ["WANDB_LOG_MODEL"]="true"

# %%
import torch
import numpy as np
from datasets import load_metric
from transformers import TrainingArguments
from transformers import Trainer

metric = load_metric("accuracy")

def compute_metrics(p):
    return metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)

def collate_fn(batch):
    return {
        'pixel_values': torch.stack([x['pixel_values'] for x in batch]),
        'labels': torch.tensor([x['label'] for x in batch])
    }

from transformers import ViTForImageClassification

labels = ds['train'].features['label'].names

model = ViTForImageClassification.from_pretrained(
    model_name_or_path,
    num_labels=len(labels),
    id2label={str(i): c for i, c in enumerate(labels)},
    label2id={c: str(i) for i, c in enumerate(labels)}
)

training_args = TrainingArguments(
  output_dir="./vit-base-beans",
  per_device_train_batch_size=16,
  evaluation_strategy="steps",
  num_train_epochs=4,
  report_to="wandb",
  fp16=False,
  save_steps=40,
  eval_steps=40,
  logging_steps=10,
  learning_rate=2e-4,
  save_total_limit=2,
  remove_unused_columns=False,
  push_to_hub=False,
  load_best_model_at_end=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=collate_fn,
    compute_metrics=compute_metrics,
    train_dataset=prepared_ds["train"],
    eval_dataset=prepared_ds["validation"],
    tokenizer=feature_extractor,
)

train_results = trainer.train()
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
# <ipython-input-6-709144c77e54>:7: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("accuracy")
# Downloading builder script:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/346M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-709144c77e54> in <module>
#      20 labels = ds['train'].features['label'].names
#      21
# ---> 22 model = ViTForImageClassification.from_pretrained(
#      23     model_name_or_path,
#      24     num_labels=len(labels),
#
# /usr/local/lib/python3.9/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    2317                         "_commit_hash": commit_hash,
#    2318                     }
# -> 2319                     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    2320
#    2321                     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#
# /usr/local/lib/python3.9/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     407     try:
#     408         # Load from URL or cache if already cached
# --> 409         resolved_file = hf_hub_download(
#     410             path_or_repo_id,
#     411             filename,
#
# /usr/local/lib/python3.9/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     118             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     119
# --> 120         return fn(*args, **kwargs)
#     121
#     122     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.9/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1298             logger.info("downloading %s to %s", url, temp_file.name)
#    1299
# -> 1300             http_get(
#    1301                 url_to_download,
#    1302                 temp_file,
#
# /usr/local/lib/python3.9/dist-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries)
#     539         if chunk:  # filter out keep-alive new chunks
#     540             progress.update(len(chunk))
# --> 541             temp_file.write(chunk)
#     542     progress.close()
#     543
#
# /usr/lib/python3.9/tempfile.py in func_wrapper(*args, **kwargs)
#     615             @_functools.wraps(func)
#     616             def func_wrapper(*args, **kwargs):
# --> 617                 return func(*args, **kwargs)
#     618             # Avoid closing the file as long as the wrapper is alive,
#     619             # see issue #18879.
#
# KeyboardInterrupt:

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from huggingface_hub import HfApi

api = HfApi()

api.upload_folder(
    folder_path="/content/vit-base-beans/checkpoint-200",
    path_in_repo = ".",
    repo_id="BlakeMartin/BeanDetect",
    repo_type="model",
    create_pr=1
)
